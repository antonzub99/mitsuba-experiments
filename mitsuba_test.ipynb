# %%
import mitsuba as mi
import drjit as dr

import os
import numpy as np

#os.environ['DRJIT_LIBLLVM_PATH'] = 'C:\ProgramFiles\LLVM\bin\LLVM-C.dll'

# %%
mi.variants()
# Out:
# ['scalar_rgb', 'scalar_spectral', 'cuda_ad_rgb', 'llvm_ad_rgb']

# %%
mi.set_variant('llvm_ad_rgb')
simple_box = mi.cornell_box()

simple_box['integrator'] = {
    'type': 'direct',
    'emitter_samples': 10,
    'bsdf_samples': 0
}
simple_box['sampler'] = {
    'type': 'independent',
    'sample_count': 64
}

scene = mi.load_dict(simple_box)

# %%
mi.render??

# %%
img = mi.render(scene, spp=25)
mi.Bitmap(img)
# Out:
# Bitmap[
#   pixel_format = rgb,
#   component_format = float32,
#   size = [256, 256],
#   srgb_gamma = 0,
#   struct = Struct<12>[
#     float32 R; // @0, premultiplied alpha
#     float32 G; // @4, premultiplied alpha
#     float32 B; // @8, premultiplied alpha
#   ],
#   data = [ 768 KiB of image data ]
# ]

# %%
mi.Bitmap(img).write('cornell_box.exr')

# %%
dragon = mi.load_file('scenes/dragon/scene.xml')

# %%
dragon_img = mi.render(dragon, spp=50)
dragon_bitmap = mi.Bitmap(dragon_img)

# %%
dragon_bitmap
# Out:
# Bitmap[
#   pixel_format = rgb,
#   component_format = float32,
#   size = [1280, 720],
#   srgb_gamma = 0,
#   struct = Struct<12>[
#     float32 R; // @0, premultiplied alpha
#     float32 G; // @4, premultiplied alpha
#     float32 B; // @8, premultiplied alpha
#   ],
#   data = [ 10.5 MiB of image data ]
# ]

# %%
veach_mis = mi.load_file('scenes/veach-mis/scene_play.xml')

veach_img = mi.render(veach_mis)
mi.Bitmap(veach_img).write('veach_direct_bsdf.exr')

# %%
veach_mis
# Out:
# Scene[
#   children = [
#     DirectIntegrator[
#       emitter_samples = 0,
#       bsdf_samples = 50
#     ],
#     PerspectiveCamera[
#       x_fov = [35],
#       near_clip = 0.01,
#       far_clip = 10000,
#       film = HDRFilm[
#         size = [1280, 720],
#         crop_size = [1280, 720],
#         crop_offset = [0, 0],
#         sample_border = 0,
#         filter = TentFilter[radius=1.000000],
#         file_format = OpenEXR,
#         pixel_format = rgb,
#         component_format = float16,
#       ],
#       sampler = IndependentSampler[
#         base_seed = 0
#         sample_count = 64
#         samples_per_wavefront = 64
#         wavefront_size = 58982400
#       ],
#       resolution = [1280, 720],
#       shutter_open = 0,
#       shutter_open_time = 0,
#       to_world = [[-4.37113e-08, 0, -1, 28.2792],
#                   [0, 1, 0, 3.5],
#                   [1, 0, -4.37113e-08, 1.23612e-06],
#                   [0, 0, 0, 1]]
#     ],
#     TwoSided[
# ...

# %%
dr.select??
